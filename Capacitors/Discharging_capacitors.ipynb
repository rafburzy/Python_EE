# %% [markdown]
# # Discharging capacitors

# %%
# Definitions of parameters of the circuit

# Capacitance of generator [F]
C = 1e-6 

# Parallel resistance (discharging the capacitor in the generator forming the tail of the impulse) [Ohm]
R1 = 4

# Series resistance (forming the head) [Ohm]
R2 = 150

# Inductance of the loop [H]
L = 1e-3

# Capacitance of the test object [F]
Co = 1e-6

# %%
# defining the time of the analysis
import numpy as np

t = np.linspace(0,6e-4, 1000)

# %% [markdown]
# ## Case1: Two capacitors and the resistor
#
# Theoretical background and derivation of the state equations
#
# <img src="two_cap.png">

# %%
# Case 1 two capacitors and the resistor

def dx1(y,t):
    uco = y[0]
    
    duco = 1/(R2*Co)*(Uo - uco - Co/C*uco)
    
    return [duco]

# %%
# initial conditions
Uo = 200
y0 = [0.0]

# %%
# time constant
Cz = C*Co/(C+Co)
R2*Cz
# Out:
# 7.5e-05

# %%
from scipy.integrate import odeint, ode, romb, cumtrapz

X1 = odeint(dx1, y0, t)

# %%
uco = X1[:,0]

# %%
# the current and the other capacitor voltage

i = 1/(R2)*(Uo - uco - Co/C*uco)

uc = Uo - Co/C*uco

# current starting value
Uo/R2

# discharge voltage

ud = C*Uo/(C+Co)

Uo/R2, ud
# Out:
# (1.3333333333333333, 100.0)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column
from bokeh.palettes import RdYlGn4

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6e37aa16-8079-43f6-9f49-76ec88ae86f1">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width=800, plot_height=400)

p.line(t, uco, color="firebrick", legend = "cap charging")
p.line(t, uc, legend = "cap discharging")

p.xaxis.axis_label = "time [s]"
p.xaxis.axis_label_text_font_size = "10pt"
p.yaxis.axis_label = "voltage [V]"
p.yaxis.axis_label_text_font_size = "10pt"

p2 = figure(plot_width=800, plot_height=400)

p2.line(t, i, color='#1a9641')

p2.xaxis.axis_label = "time [s]"
p2.xaxis.axis_label_text_font_size = "10pt"
p2.yaxis.axis_label = "current [A]"
p2.yaxis.axis_label_text_font_size = "10pt"

show(column(p, p2))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ac0f71ac-d6a4-4f0a-b897-9568709d879a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ac0f71ac-d6a4-4f0a-b897-9568709d879a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ac0f71ac-d6a4-4f0a-b897-9568709d879a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ac0f71ac-d6a4-4f0a-b897-9568709d879a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5366dd35-6397-434b-877d-6974772dc890":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0896bc93-a63c-42e5-8aa5-a806aa6da5e3","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"41a365ad-f8ca-4866-a514-efe79872f784","type":"Line"},{"attributes":{"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"c5aacfaa-80fd-459c-816a-7abc0a8cd138","type":"PanTool"},{"attributes":{"label":{"value":"cap charging"},"renderers":[{"id":"eafc5356-4ac7-4b8e-8a8f-8dd1d04e0bbc","type":"GlyphRenderer"}]},"id":"ee320f66-553a-4ad3-88a5-ad5cafc94e06","type":"LegendItem"},{"attributes":{"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"8e4a3540-5474-4ed5-b52d-966bf7d16a7b","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"9e07a531-b09c-4775-a3cb-5e6826f37fee","type":"BoxAnnotation"},"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"4a5076b6-668e-4193-9957-b20a103f11b1","type":"BoxZoomTool"},{"attributes":{"items":[{"id":"ee320f66-553a-4ad3-88a5-ad5cafc94e06","type":"LegendItem"},{"id":"93f870b5-caa8-4956-9c8e-fc9d6b3f7564","type":"LegendItem"}],"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"555ee672-4a23-4d31-b75a-15c69bb797a0","type":"Legend"},{"attributes":{"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"4e778dba-c20d-4b8a-9ff0-0dede4cc396f","type":"SaveTool"},{"attributes":{"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"7e5387d8-a061-4b2b-9d0e-b971f764a416","type":"ResetTool"},{"attributes":{"plot":{"id":"89887814-30bb-4976-a9f9-0458dde74819","subtype":"Figure","type":"Plot"}},"id":"bd734af2-9d3c-492c-8201-62ecdd0bcd00","type":"HelpTool"},{"attributes":{"below":[{"id":"3057cc54-efc7-48ca-a704-fa2e5b9b4621","type":"LinearAxis"}],"left":[{"id":"2a950123-f006-4d3c-a366-f523b973140b","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"3057cc54-efc7-48ca-a704-fa2e5b9b4621","type":"LinearAxis"},{"id":"69741a24-22fb-440a-bb13-e336013f8b2a","type":"Grid"},{"id":"2a950123-f006-4d3c-a366-f523b973140b","type":"LinearAxis"},{"id":"1acc507e-5f66-45e0-89a8-f3a854b00601","type":"Grid"},{"id":"2069a57f-630a-43ee-b0a6-be681f7ad096","type":"BoxAnnotation"},{"id":"ee4062b3-9b62-4325-810a-97c641475302","type":"GlyphRenderer"}],"title":{"id":"b37aeaef-bf02-4a63-bf41-01fea7be5d7d","type":"Title"},"tool_events":{"id":"32774347-02b3-44a6-802e-1c61b57a0ca2","type":"ToolEvents"},"toolbar":{"id":"6074d885-c356-45a8-877c-4dcf7db3d379","type":"Toolbar"},"x_range":{"id":"26a11b97-e892-463c-a130-faf9176e001a","type":"DataRange1d"},"y_range":{"id":"15b1fb1c-af21-4ed9-ba28-f1f130cb4655","type":"DataRange1d"}},"id":"e3075f11-027f-42a3-84d9-85a8ff29483f","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"e2df41f4-53c4-4d15-bb68-78654b507e6a","type":"ColumnDataSource"},"glyph":{"id":"41a365ad-f8ca-4866-a514-efe79872f784","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"0896bc93-a63c-42e5-8aa5-a806aa6da5e3","type":"Line"},"selection_glyph":null},"id":"72f78478-7802-41fe-924a-0cde95ea2cc3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"7f6cba57-0254-4df2-bfdc-a593e27108b1","type":"ColumnDataSource"},"glyph":{"id":"7788cffa-08f0-4b26-b6b6-61a6f8e1227a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b9508fbb-0054-401b-ad50-325d683ad4c9","type":"Line"},"selection_glyph":null},"id":"ee4062b3-9b62-4325-810a-97c641475302","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"7f6cba57-0254-4df2-bfdc-a593e27108b1","typ ...

# %% [markdown]
# ## Case 2: Two capacitors, resistor and an inductor
#
# Theoretical background and state equations derivation:
#
# <img src="two_cap_ind.png">

# %%
# Adjustment of parameters for case 2

L = 1e-2 # interesting values for L: 1e-3 (very little influence); 5e-3 (small oscillation); 1e-2 bigger oscillation
t2 = np.linspace(0,10e-4,1000)

# %%
# Case 2: two capacitors, resistor and inductor

def dx2(y,t):
    i, uco = y[0], y[1]
    
    di = 1/L*(Uo - Co/C*uco - i*R2 - uco)
    duco = 1/Co*i
    
    return [di, duco]

# %%
# initial conditions
Uo = 200

y02 = [0.0, 0.0]

# %%
X2 = odeint(dx2, y02, t2)

# %%
i2 = X2[:,0]
uco2 = X2[:,1]

uc2 = Uo - Co/C*uco2

# %%
p3 = figure(plot_width=800, plot_height=400)

p3.line(t2, uco2, color="firebrick", legend = "cap charging")
p3.line(t2, uc2, legend = "cap discharging")

p3.xaxis.axis_label = "time [s]"
p3.xaxis.axis_label_text_font_size = "10pt"
p3.yaxis.axis_label = "voltage [V]"
p3.yaxis.axis_label_text_font_size = "10pt"

p4 = figure(plot_width=800, plot_height=400)

p4.line(t2, i2, color='#1a9641')

p4.xaxis.axis_label = "time [s]"
p4.xaxis.axis_label_text_font_size = "10pt"
p4.yaxis.axis_label = "current [A]"
p4.yaxis.axis_label_text_font_size = "10pt"

show(column(p3, p4))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5172f744-4446-4d8b-b378-ee849c93bd57"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("5172f744-4446-4d8b-b378-ee849c93bd57").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5172f744-4446-4d8b-b378-ee849c93bd57");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5172f744-4446-4d8b-b378-ee849c93bd57' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"fba0c532-1f65-4c1c-90c4-9d45df04a7f7":{"roots":{"references":[{"attributes":{"plot":{"id":"2d516d18-a88c-4f5d-b459-04d90bb7598b","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d6aeb13-6ed0-4927-850f-fe26f8a75438","type":"BasicTicker"}},"id":"beb4d633-462b-4f68-b67e-1e50977be6f4","type":"Grid"},{"attributes":{},"id":"7d6aeb13-6ed0-4927-850f-fe26f8a75438","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"882f75b7-a7a5-481a-95e6-1dcd32f38bc0","type":"PanTool"},{"id":"646f75c3-c5d8-4f1b-a432-ed6167936007","type":"WheelZoomTool"},{"id":"a941f929-f083-4902-a622-5854a986fbf3","type":"BoxZoomTool"},{"id":"af9cea28-569e-4fbf-9dc8-c3efcad0ab79","type":"SaveTool"},{"id":"db3009eb-155d-4087-9a50-85a5d78aeaf5","type":"ResetTool"},{"id":"46dc9f23-6b95-414a-bf87-cea8a3f4d638","type":"HelpTool"}]},"id":"2e70a07d-2f73-490c-92bb-e889db6b7dc5","type":"Toolbar"},{"attributes":{},"id":"d60661f9-6675-46f6-a4e8-70f920b50be8","type":"ToolEvents"},{"attributes":{"data_source":{"id":"1c73a7c7-a67b-49e4-9d29-f56b5af8b8a8","type":"ColumnDataSource"},"glyph":{"id":"32ea949f-8e4e-4a29-8b27-0150b15da701","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"5ee04bdf-1c07-49b9-b455-79c71d70fe03","type":"Line"},"selection_glyph":null},"id":"d4a2e3d8-2e42-4871-a43f-1e4511705590","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5ee04bdf-1c07-49b9-b455-79c71d70fe03","type":"Line"},{"attributes":{"axis_label":"time [s]","formatter":{"id":"36e76b8d-f9a7-4734-8764-b3598eca2e70","type":"BasicTickFormatter"},"plot":{"id":"2d516d18-a88c-4f5d-b459-04d90bb7598b","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d6aeb13-6ed0-4927-850f-fe26f8a75438","type":"BasicTicker"}},"id":"c85e8289-5688-4cd1-a2f5-7b9a818d33b0","type":"LinearAxis"},{"attributes":{"label":{"value":"cap discharging"},"renderers":[{"id":"d4a2e3d8-2e42-4871-a43f-1e4511705590","type":"GlyphRenderer"}]},"id":"08451e9e-68fe-4be5-8d36-dcec31bc07d3","type":"LegendItem"},{"attributes":{"line_color":{"value":"#1a9641"},"x":{"field":"x"},"y":{"field":"y"}},"id":"03f36290-ca84-4b85-8a2e-f4e628d2cbbb","type":"Line"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"32ea949f-8e4e-4a29-8b27-0150b15da701","type":"Line"},{"attributes":{"callback":null},"id":"d278ca86-bdf2-4529-bbb9-591de75e8b96","type":"DataRange1d"},{"attributes":{"below":[{"id":"6d8bc11e-eddd-47f3-b4b5-150a35ee532d","type":"LinearAxis"}],"left":[{"id":"399cc907-4948-4232-b753-f6a3c8aac45a","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"6d8bc11e-eddd-47f3-b4b5-150a35ee532d","type":"LinearAxis"},{"id":"ec7cac9b-3b9c-4958-a96e-47ed76541386","type":"Grid"},{"id":"399cc907-4948-4232-b753-f6a3c8aac45a","type":"LinearAxis"},{"id":"674f6e0a-a354-4ef8-9c69-bbb412c8c57e","type":"Grid"},{"id":"99c70d17-8d78-4741-a4c3-950a7c1b466b","type":"BoxAnnotation"},{"id":"c9e93605-97b5-413a-9539-28672ee9b238","type":"Legend"},{"id":"e919a11a-f5c8-41c3-890f-092a2bd64884","type":"GlyphRenderer"},{"id":"d4a2e3d8-2e42-4871-a43f-1e4511705590","type":"GlyphRenderer"}],"title":{"id":"dbcb71b5-a754-4979-81e2-27ebe0ec101e","type":"Title"},"tool_events":{"id":"25479979-bb6a-4307-8042-dfab2eedb808","type":"ToolEvents"},"toolbar":{"id":"5ab73e08-ac90-4835-ba35-3443db1561a2","type":"Toolbar"},"x_range":{"id":"d3a44329-020b-42eb-80bb-d2ece793dfb5","type":"DataRange1d"},"y_range":{"id":"d4a90d8e-fb99-44c9-b461-05cf013ad3e7","type":"DataRange1d"}},"id":"da44ef66-9a18-41b2-8bc4-dc8cf0a7b240","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a676a89f-7ac7-4956-a03e-2bc8f442ad71","type":"Line"},{"attributes":{},"id":"c64ca483-9985-4cc9-bee5-29872fb1d6d2","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_ ...

# %% [markdown]
# ## Case 3: Circuit of the impulse withstand tester
#
# Theoretical background and the state equations derivation
#
# <img src="imp_withstand.png">

# %%
# Adjustment of parameters for case 3

L = 1e-3 # interesting values for L: 1e-3 (very little influence); 5e-3 (small oscillation); 1e-2 bigger oscillation
t3 = np.linspace(0,10e-4,1000)

# %%
# Case 3: circuit for the impulse withstand tester

def dx(y,t):
    #state vector variables
    i2, uco, uc = y[0], y[1], y[2]
    
   
    di2 = 1/L*(uc-i2*R2-uco)
    duco = 1/Co*i2
    duc = -1/C*(uc/R1+i2)
        
    return [di2, duco, duc]

# %%
# initial conditions

# capacitor voltage [V]
Uo = 200

# vector of the initial conditions

y0 = [0.0, 0.0, Uo]

# %%
#from scipy.integrate import odeint, ode, romb, cumtrapz

X = odeint(dx, y0, t3)

# %%
i2 = X[:,0]
uco = X[:,1]
uc = X[:,2]

# %%
#output_notebook()

p5 = figure(plot_width=800, plot_height=400)

p5.line(t3, uco, color="firebrick", legend ="Object")

p5.xaxis.axis_label = "time [s]"
p5.xaxis.axis_label_text_font_size = "10pt"
p5.yaxis.axis_label = "voltage [V]"
p5.yaxis.axis_label_text_font_size = "10pt"

p7 = figure(plot_width=800, plot_height=400)

p7.line(t3, uc, legend = "Main capacitor")

p7.xaxis.axis_label = "time [s]"
p7.xaxis.axis_label_text_font_size = "10pt"
p7.yaxis.axis_label = "voltage [V]"
p7.yaxis.axis_label_text_font_size = "10pt"

p6 = figure(plot_width=800, plot_height=400)

p6.line(t3, i2, color='#1a9641')

p6.xaxis.axis_label = "time [s]"
p6.xaxis.axis_label_text_font_size = "10pt"
p6.yaxis.axis_label = "current [A]"
p6.yaxis.axis_label_text_font_size = "10pt"

show(column(p5, p7, p6))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1f01eb7f-968b-46c1-bb34-23b1abdcfb0f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1f01eb7f-968b-46c1-bb34-23b1abdcfb0f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1f01eb7f-968b-46c1-bb34-23b1abdcfb0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1f01eb7f-968b-46c1-bb34-23b1abdcfb0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1fcf4447-e584-4e8c-871d-9bddb48963e2":{"roots":{"references":[{"attributes":{},"id":"3963b648-2acb-45e3-8238-8d781d12d69b","type":"BasicTickFormatter"},{"attributes":{},"id":"256806d1-a550-4113-9d02-fc7e25b07ee6","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"74522275-7cbb-4294-81d7-c893be1bd8b9","type":"Title"},{"attributes":{"plot":{"id":"b5e7db62-bc34-417a-8b09-3b4e5ca56c9e","subtype":"Figure","type":"Plot"}},"id":"c958e178-dec5-4571-803a-7a7f0d3cd9e0","type":"ResetTool"},{"attributes":{"plot":{"id":"b5e7db62-bc34-417a-8b09-3b4e5ca56c9e","subtype":"Figure","type":"Plot"}},"id":"61b60eb8-ac3f-4965-b1fd-e74652fc1ac3","type":"SaveTool"},{"attributes":{"callback":null},"id":"a74bca6f-19f4-4430-bd0f-ed281e58dfc4","type":"DataRange1d"},{"attributes":{"plot":{"id":"b5e7db62-bc34-417a-8b09-3b4e5ca56c9e","subtype":"Figure","type":"Plot"}},"id":"53091961-ce36-4844-95e4-a89c55073962","type":"WheelZoomTool"},{"attributes":{"label":{"value":"Main capacitor"},"renderers":[{"id":"ca652b77-a0be-4146-9ccb-c67f8939bc8b","type":"GlyphRenderer"}]},"id":"c33d4aea-b0d9-4d3d-86c6-c927acb66495","type":"LegendItem"},{"attributes":{"plot":{"id":"b5e7db62-bc34-417a-8b09-3b4e5ca56c9e","subtype":"Figure","type":"Plot"}},"id":"1f8af5c5-a977-450d-9455-c5aeac12fadb","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"aae68b73-44b6-45ae-99a1-67cb4c2bff7e","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Object"},"renderers":[{"id":"f358f282-2951-490e-8829-3718f6bff1f3","type":"GlyphRenderer"}]},"id":"db38b5b2-fd13-4423-b74f-de4a71c8e3e5","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d1a54c02-6f98-43bd-a860-f2752ecba05a","type":"BoxAnnotation"},{"attributes":{"items":[{"id":"db38b5b2-fd13-4423-b74f-de4a71c8e3e5","type":"LegendItem"}],"plot":{"id":"497d6c1e-96a4-4d52-bb95-db70c2a892f1","subtype":"Figure","type":"Plot"}},"id":"eae91841-665a-445b-9a17-23d33f8992b4","type":"Legend"},{"attributes":{"data_source":{"id":"31ccf332-9671-4e2b-a0de-a2a8f0932c09","type":"ColumnDataSource"},"glyph":{"id":"d947218d-7753-4ac3-9373-015d0ee3c70d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c0ffa9b6-8a72-406a-bec6-a4b3b8a5ddf4","type":"Line"},"selection_glyph":null},"id":"f358f282-2951-490e-8829-3718f6bff1f3","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"b8615b16-2d5a-479b-b56e-d1412228acf8","type":"LinearAxis"}],"left":[{"id":"293bf34a-0d26-4981-bb31-147fb6fb164a","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"b8615b16-2d5a-479b-b56e-d1412228acf8","type":"LinearAxis"},{"id":"cc9157d6-4a5d-42ce-9df7-1a559f9b12e2","type":"Grid"},{"id":"293bf34a-0d26-4981-bb31-147fb6fb164a","type":"LinearAxis"},{"id":"eb27103e-043e-45e8-92ce-598eabd5e82a","type":"Grid"},{"id":"67c20ffe-350c-41e1-81da-090c56c6576d","type":"BoxAnnotation"},{"id":"eae91841-665a-445b-9a17-23d33f8992b4","type":"Legend"},{"id":"f358f282-2951-490e-8829-3718f6bff1f3","type":"GlyphRenderer"}],"title":{"id":"74522275-7cbb-4294-81d7-c893be1bd8b9","type":"Title"},"tool_events":{"id":"e879ae45-240b-40e6-bb85-a2a91f9b4d11","type":"ToolEvents"},"toolbar":{"id":"678bf8ff-f796-48a9-a170-8b7ed0d1ae62","type":"Toolbar"},"x_range":{"id":"1d8d143c-cab5-4e39-86a8-ede1afdf936e","type":"DataRange1d"},"y_range":{"id":"6fe81f92-f733-4d3f-8da0-e68438788cf4","type":"DataRange1d"}},"id":"497d6c1e-96a4-4d52-bb95-db70c2a892f1","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}}, ...

# %% [markdown]
# ## Case 4: Capacitor discharge to a resistor
#
# <img src="cap_discharge.png">

# %%
# Capacitor discharging to a resistor

def dk(y,t):
    u = y[0]
    
    du = -1/(R1*C)*u
    
    return [du]

# %%
y03 = [200.0]

# %%
X5 = odeint(dk, y03, t3)

# %%
u = X5[:,0]

# %%
p7 = figure(plot_width=800, plot_height=400, x_range = (0,4e-5))

p7.line(t3, u, color="firebrick")

p7.xaxis.axis_label = "time [s]"
p7.xaxis.axis_label_text_font_size = "10pt"
p7.yaxis.axis_label = "voltage [V]"
p7.yaxis.axis_label_text_font_size = "10pt"

show(p7)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1f02f573-ad6b-4f36-8030-f460df121120"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1f02f573-ad6b-4f36-8030-f460df121120").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1f02f573-ad6b-4f36-8030-f460df121120");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1f02f573-ad6b-4f36-8030-f460df121120' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"69611bed-c6d9-4bf5-9fb4-38b41c3ee9ac":{"roots":{"references":[{"attributes":{"axis_label":"voltage [V]","formatter":{"id":"ce2da7c0-27b3-48a3-9c23-8f0fa12a9f69","type":"BasicTickFormatter"},"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"e4676dae-785f-4c52-a25e-946b2df0b5d9","type":"BasicTicker"}},"id":"2fe90edf-9be6-4ac2-9499-cb521bd3d87a","type":"LinearAxis"},{"attributes":{},"id":"c35adef4-69ee-437f-8027-1be7c563d904","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"},"ticker":{"id":"e4676dae-785f-4c52-a25e-946b2df0b5d9","type":"BasicTicker"}},"id":"8fcc4ea2-1754-450a-9100-9cab77cb1c5c","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6dcaafdf-8432-4796-9b00-ce6d42de5674","type":"Line"},{"attributes":{},"id":"e4676dae-785f-4c52-a25e-946b2df0b5d9","type":"BasicTicker"},{"attributes":{"plot":null,"text":""},"id":"a71601c5-612a-46c4-8635-52a1c2499938","type":"Title"},{"attributes":{},"id":"ce2da7c0-27b3-48a3-9c23-8f0fa12a9f69","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"6e27f0f7-03ea-444f-94f6-46475ad09002","type":"ResetTool"},{"attributes":{"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"343952a4-e575-4bab-8759-7f0595794bef","type":"PanTool"},{"attributes":{"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"252b0761-aaf4-446f-a1e8-d5ef91d437cb","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b20dcb90-2cc5-4b4f-941f-f6684b9398f5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"3f8bef3f-26de-41ed-9b56-a6c24c6f1638","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"b20dcb90-2cc5-4b4f-941f-f6684b9398f5","type":"BoxAnnotation"},"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"97d3e19e-9ed9-4cfe-9b9e-0d23fc697671","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"}},"id":"593b5289-de1c-4a9b-b548-125bcdf088e7","type":"HelpTool"},{"attributes":{"below":[{"id":"fbcef5f4-ff7d-49ff-b7e2-70457e48b135","type":"LinearAxis"}],"left":[{"id":"2fe90edf-9be6-4ac2-9499-cb521bd3d87a","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"fbcef5f4-ff7d-49ff-b7e2-70457e48b135","type":"LinearAxis"},{"id":"bb4343ff-db12-429d-95d7-55fd13e0110c","type":"Grid"},{"id":"2fe90edf-9be6-4ac2-9499-cb521bd3d87a","type":"LinearAxis"},{"id":"8fcc4ea2-1754-450a-9100-9cab77cb1c5c","type":"Grid"},{"id":"b20dcb90-2cc5-4b4f-941f-f6684b9398f5","type":"BoxAnnotation"},{"id":"f3ecfb0c-4de9-465a-a387-d445ef6b4255","type":"GlyphRenderer"}],"title":{"id":"a71601c5-612a-46c4-8635-52a1c2499938","type":"Title"},"tool_events":{"id":"a5349d1b-0841-4011-921d-401abcd7c0e9","type":"ToolEvents"},"toolbar":{"id":"f5c2eaa8-2731-4bb5-a40e-9e39aee16032","type":"Toolbar"},"x_range":{"id":"b3e073fd-5e16-4026-b60a-6e102c1b437c","type":"Range1d"},"y_range":{"id":"26d2b8c7-b164-411b-8d08-98f9af20a2a1","type":"DataRange1d"}},"id":"33c7c393-7c3c-4ef2-a036-3c7d6c26cdb3","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"944187eb-96ae-4105-b82f-cdb880c8c07d","type":"ColumnDataSource"},{ ...
