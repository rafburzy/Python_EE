# %% [markdown]
# # Discharging capacitors

# %%
# Definitions of parameters of the circuit

# Capacitance of generator [F]
C = 1e-6 

# Parallel resistance (discharging the capacitor in the generator forming the tail of the impulse) [Ohm]
R1 = 4

# Series resistance (forming the head) [Ohm]
R2 = 150

# Inductance of the loop [H]
L = 1e-3

# Capacitance of the test object [F]
Co = 1e-6

# %%
# defining the time of the analysis
import numpy as np

t = np.linspace(0,6e-4, 1000)

# %% [markdown]
# ## Case1: Two capacitors and the resistor
#
# Theoretical background and derivation of the state equations
#
# <img src="two_cap.png">

# %%
# Case 1 two capacitors and the resistor

def dx1(y,t):
    uco = y[0]
    
    duco = 1/(R2*Co)*(Uo - uco - Co/C*uco)
    
    return [duco]

# %%
# initial conditions
Uo = 200
y0 = [0.0]

# %%
# time constant
Cz = C*Co/(C+Co)
R2*Cz
# Out:
# 7.5e-05

# %%
from scipy.integrate import odeint, ode, romb, cumtrapz

X1 = odeint(dx1, y0, t)

# %%
uco = X1[:,0]

# %%
# the current and the other capacitor voltage

i = 1/(R2)*(Uo - uco - Co/C*uco)

uc = Uo - Co/C*uco

# current starting value
Uo/R2

# discharge voltage

ud = C*Uo/(C+Co)

Uo/R2, ud
# Out:
# (1.3333333333333333, 100.0)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column
from bokeh.palettes import RdYlGn4

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7aa02e18-9526-48d1-ad1a-bb41c64514a7">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width=800, plot_height=400)

p.line(t, uco, color="firebrick", legend = "cap charging")
p.line(t, uc, legend = "cap discharging")

p.xaxis.axis_label = "time [s]"
p.xaxis.axis_label_text_font_size = "10pt"
p.yaxis.axis_label = "voltage [V]"
p.yaxis.axis_label_text_font_size = "10pt"

p2 = figure(plot_width=800, plot_height=400)

p2.line(t, i, color='#1a9641')

p2.xaxis.axis_label = "time [s]"
p2.xaxis.axis_label_text_font_size = "10pt"
p2.yaxis.axis_label = "current [A]"
p2.yaxis.axis_label_text_font_size = "10pt"

show(column(p, p2))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="83a819f3-c7bf-49b7-b189-21042a214dcf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83a819f3-c7bf-49b7-b189-21042a214dcf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83a819f3-c7bf-49b7-b189-21042a214dcf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b95b156b-273f-4010-b702-e3ce4a0b0f4f":{"roots":{"references":[{"attributes":{"data_source":{"id":"26c1558d-ea71-4018-8ec6-5a0fbd5b7c8a","type":"ColumnDataSource"},"glyph":{"id":"41ce2839-26df-423d-a376-fcf7c6540270","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"7695af6d-13a7-4e29-8ca6-0b32d44c3363","type":"Line"},"selection_glyph":null},"id":"741a758a-4a19-4abd-b365-a4f065efbbe5","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"047b74d8-9f59-4f30-85d9-39cb2b497f8d","subtype":"Figure","type":"Plot"},"ticker":{"id":"c9dc5981-fe9b-4bd7-b9f9-893061e61bf3","type":"BasicTicker"}},"id":"b0e8b99a-ea91-47e9-8bbd-56bba334343c","type":"Grid"},{"attributes":{"plot":{"id":"908e101d-b692-4668-8314-583b80813a4a","subtype":"Figure","type":"Plot"}},"id":"32ba050d-168c-4e2f-9f9e-6194d78a5137","type":"SaveTool"},{"attributes":{"below":[{"id":"50cc181d-b9b9-4d22-8a5f-fd4f6afdc4d2","type":"LinearAxis"}],"left":[{"id":"2ee4572d-0933-443d-84e6-c912bcdd5311","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[39]</strong>&gt;</code></p>

# %% [markdown]
# ## Case 2: Two capacitors, resistor and an inductor
#
# Theoretical background and state equations derivation:
#
# <img src="two_cap_ind.png">

# %%
# Adjustment of parameters for case 2

L = 1e-2 # interesting values for L: 1e-3 (very little influence); 5e-3 (small oscillation); 1e-2 bigger oscillation
t2 = np.linspace(0,10e-4,1000)

# %%
# Case 2: two capacitors, resistor and inductor

def dx2(y,t):
    i, uco = y[0], y[1]
    
    di = 1/L*(Uo - Co/C*uco - i*R2 - uco)
    duco = 1/Co*i
    
    return [di, duco]

# %%
# initial conditions
Uo = 200

y02 = [0.0, 0.0]

# %%
X2 = odeint(dx2, y02, t2)

# %%
i2 = X2[:,0]
uco2 = X2[:,1]

uc2 = Uo - Co/C*uco2

# %%
p3 = figure(plot_width=800, plot_height=400)

p3.line(t2, uco2, color="firebrick", legend = "cap charging")
p3.line(t2, uc2, legend = "cap discharging")

p3.xaxis.axis_label = "time [s]"
p3.xaxis.axis_label_text_font_size = "10pt"
p3.yaxis.axis_label = "voltage [V]"
p3.yaxis.axis_label_text_font_size = "10pt"

p4 = figure(plot_width=800, plot_height=400)

p4.line(t2, i2, color='#1a9641')

p4.xaxis.axis_label = "time [s]"
p4.xaxis.axis_label_text_font_size = "10pt"
p4.yaxis.axis_label = "current [A]"
p4.yaxis.axis_label_text_font_size = "10pt"

show(column(p3, p4))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="01486272-6ec0-4d1f-a89c-913584b104b8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("01486272-6ec0-4d1f-a89c-913584b104b8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '01486272-6ec0-4d1f-a89c-913584b104b8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9c151fa1-8eba-406b-919e-09dbd6880e57":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,1.001001001001001e-06,2.002002002002002e-06,3.0030030030030026e-06,4.004004004004004e-06,5.005005005005005e-06,6.006006006006005e-06,7.007007007007006e-06,8.008008008008007e-06,9.009009009009008e-06,1.001001001001001e-05,1.101101101101101e-05,1.201201201201201e-05,1.3013013013013012e-05,1.4014014014014013e-05,1.5015015015015015e-05,1.6016016016016015e-05,1.7017017017017017e-05,1.8018018018018016e-05,1.9019019019019018e-05,2.002002002002002e-05,2.1021021021021018e-05,2.202202202202202e-05,2.3023023023023022e-05,2.402402402402402e-05,2.5025025025025023e-05,2.6026026026026025e-05,2.7027027027027027e-05,2.8028028028028025e-05,2.9029029029029027e-05,3.003003003003003e-05,3.103103103103103e-05,3.203203203203203e-05,3.303303303303303e-05,3.4034034034034034e-05,3.503503503503503e-05,3.603603603603603e-05,3.7037037037037037e-05,3.8038038038038035e-05,3.9039039039039034e-05,4.004004004004004e-05,4.104104104104104e-05,4.2042042042042036e-05,4.304304304304304e-05,4.404404404404404e-05,4.504504504504504e-05,4.6046046046046044e-05,4.704704704704704e-05,4.804804804804804e-05,4.904904904904905e-05,5.0050050050050046e-05,5.105105105105105e-05,5.205205205205205e-05,5.305305305305305e-05,5.4054054054054054e-05,5.505505505505505e-05,5.605605605605605e-05,5.7057057057057056e-05,5.8058058058058055e-05,5.905905905905905e-05,6.006006006006006e-05,6.106106106106105e-05,6.206206206206206e-05,6.306306306306306e-05,6.406406406406406e-05,6.506506506506506e-05,6.606606606606606e-05,6.706706706706707e-05,6.806806806806807e-05,6.906906906906907e-05,7.007007007007007e-05,7.107107107107106e-05,7.207207207207206e-05,7.307307307307307e-05,7.407407407407407e-05,7.507507507507507e-05,7.607607607607607e-05,7.707707707707707e-05,7.807807807807807e-05,7.907907907907908e-05,8.008008008008008e-05,8.108108108108108e-05,8.208208208208208e-05,8.308308308308307e-05,8.408408408408407e-05,8.508508508508508e-05,8.608608608608608e-05,8.708708708708708e-05,8.808808808808808e-05,8.908908908908908e-05,9.009009009009008e-05,9.109109109109109e-05,9.209209209209209e-05,9.309309309309309e-05,9.409409409409409e-05,9.509509509509508e-05,9.609609609609608e-05,9.70970970970971e-05,9.80980980980981e-05,9.909909909909909e-05,0.00010010010010010009,0.00010110110110110109,0.0001021021021021021,0.0001031031031031031,0.0001041041041041041,0.0001051051051051051,0.0001061061061061061,0.0001071071071071071,0.00010810810810810811,0.0001091091091091091,0.0001101101101101101,0.0001111111111111111,0.0001121121121121121,0.0001131131131131131,0.00011411411411411411,0.00011511511511511511,0.00011611611611611611,0.00011711711711711711,0.0001181181181181181,0.0001191191191191191,0.00012012012012012012,0.00012112112112112112,0.0001221221221221221,0.00012312312312312313,0.00012412412412412413,0.00012512512512512512,0.00012612612612612612,0.00012712712712712712,0.00012812812812812812,0.00012912912912912912,0.00013013013013013012,0.00013113113113113112,0.00013213213213213211,0.0001331331331331331,0.00013413413413413414,0.00013513513513513514,0.00013613613613613614,0.00013713713713713713,0.00013813813813813813,0.00013913913913913913,0.00014014014014014013,0.00014114114114114113,0.00014214214214214213,0.00014314314314314313,0.00014414414414414412,0.00014514514514514512,0.00014614614614614615,0.00014714714714714715,0.00014814814814814815,0.00014914914914914914,0.00015015015015015014,0.00015115115115115114,0.00015215215215215214,0.00015315315315315314,0.00015415415415415414,0.00015515515515515514,0.00015615615615615614,0.00015715715715715713,0.00015815815815815816,0.00015915915915915916,0.00016016016016016016,0.00016116116116116116,0.00016216216216216215,0.00016316316316316315,0.00016416416416416415,0.00016516516516516515,0.00016616616616616615,0.00016716716716716715,0.00016816816816816815,0.00016916916916916917,0.00017017017017017017,0.00017117117117 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[45]</strong>&gt;</code></p>

# %% [markdown]
# ## Case 3: Circuit of the impulse withstand tester
#
# Theoretical background and the state equations derivation
#
# <img src="imp_withstand.png">

# %%
# Adjustment of parameters for case 3

L = 1e-3 # interesting values for L: 1e-3 (very little influence); 5e-3 (small oscillation); 1e-2 bigger oscillation
t3 = np.linspace(0,10e-4,1000)

# %%
# Case 3: circuit for the impulse withstand tester

def dx(y,t):
    #state vector variables
    i2, uco, uc = y[0], y[1], y[2]
    
   
    di2 = 1/L*(uc-i2*R2-uco)
    duco = 1/Co*i2
    duc = -1/C*(uc/R1+i2)
        
    return [di2, duco, duc]

# %%
# initial conditions

# capacitor voltage [V]
Uo = 200

# vector of the initial conditions

y0 = [0.0, 0.0, Uo]

# %%
#from scipy.integrate import odeint, ode, romb, cumtrapz

X = odeint(dx, y0, t3)

# %%
i2 = X[:,0]
uco = X[:,1]
uc = X[:,2]

# %%
#output_notebook()

p5 = figure(plot_width=800, plot_height=400)

p5.line(t3, uco, color="firebrick", legend ="Object")

p5.xaxis.axis_label = "time [s]"
p5.xaxis.axis_label_text_font_size = "10pt"
p5.yaxis.axis_label = "voltage [V]"
p5.yaxis.axis_label_text_font_size = "10pt"

p7 = figure(plot_width=800, plot_height=400)

p7.line(t3, uc, legend = "Main capacitor")

p7.xaxis.axis_label = "time [s]"
p7.xaxis.axis_label_text_font_size = "10pt"
p7.yaxis.axis_label = "voltage [V]"
p7.yaxis.axis_label_text_font_size = "10pt"

p6 = figure(plot_width=800, plot_height=400)

p6.line(t3, i2, color='#1a9641')

p6.xaxis.axis_label = "time [s]"
p6.xaxis.axis_label_text_font_size = "10pt"
p6.yaxis.axis_label = "current [A]"
p6.yaxis.axis_label_text_font_size = "10pt"

show(column(p5, p7, p6))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b1d227c4-8b06-44e7-a4b4-57ff2fecb112"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1d227c4-8b06-44e7-a4b4-57ff2fecb112");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1d227c4-8b06-44e7-a4b4-57ff2fecb112' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"40503313-a25c-4d63-befa-0da08c9a35cb":{"roots":{"references":[{"attributes":{"callback":null},"id":"ef8d3f2c-4f56-47dd-a6c5-283efe585e82","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cfee7782-fc9f-4014-9ff3-549caf0ea3db","type":"BoxAnnotation"},{"attributes":{"below":[{"id":"b589e1d9-e278-454d-8d00-f1dc88693023","type":"LinearAxis"}],"left":[{"id":"a636ad26-c070-428d-a682-247a3dba2aae","type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"b589e1d9-e278-454d-8d00-f1dc88693023","type":"LinearAxis"},{"id":"a84f35d4-d698-4849-b3b5-88e426f0d445","type":"Grid"},{"id":"a636ad26-c070-428d-a682-247a3dba2aae","type":"LinearAxis"},{"id":"37c1ad9e-6354-46b8-90ee-4c1b4f344903","type":"Grid"},{"id":"a258570e-0c68-4bdf-9c65-dabb0e83be85","type":"BoxAnnotation"},{"id":"1283a605-6b42-409e-9179-c0d2f4c01cc8","type":"Legend"},{"id":"4770fa11-5c3e-4386-8412-d8d200d371b7","type":"GlyphRenderer"}],"title":{"id":"f27db3cf-1a88-4569-8f2f-e36141efb3e3","type":"Title"},"tool_events":{"id":"6ab56075-2173-44f5-8c51-e3e317933adc","type":"ToolEvents"},"toolbar":{"id":"29e5ef92-fe68-46c1-9057-409f4ad1970b","type":"Toolbar"},"x_range":{"id":"163147b6-c4b2-455f-b3d8-4becc5dead4f","type":"DataRange1d"},"y_range":{"id":"e418c68c-0715-4f9f-8bfc-d1773532edd1","type":"DataRange1d"}},"id":"b0d4d9e9-8fbb-4604-a677-062d0cc7dfac","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"7fb8a150-e2db-4f2c-aa81-d6e8c91fedbd","type":"BasicTickFormatter"},{"attributes":{"axis_label":"time [s]","formatter":{"id":"7fb8a150-e2db-4f2c-aa81-d6e8c91fedbd","type":"BasicTickFormatter"},"plot":{"id":"9cba52d9-8a5a-4f09-a3b9-df4327db472c","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f5e0095-3a26-4a59-ad93-0119259eb772","type":"BasicTicker"}},"id":"73e16c88-3e3c-4a93-8333-41e6778b2855","type":"LinearAxis"},{"attributes":{},"id":"7dfc7a02-2ae2-4ba5-b086-289533384de3","type":"BasicTicker"},{"attributes":{"plot":{"id":"b0d4d9e9-8fbb-4604-a677-062d0cc7dfac","subtype":"Figure","type":"Plot"}},"id":"76d33c66-255a-439e-ae8d-6d9b6e28d74d","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"9cba52d9-8a5a-4f09-a3b9-df4327db472c","subtype":"Figure","type":"Plot"}},"id":"2a282b35-38cf-4067-bc55-a4e8426a92e0","type":"SaveTool"},{"attributes":{"plot":{"id":"555678be-68f3-4cf7-8233-3d9495927257","subtype":"Figure","type":"Plot"},"ticker":{"id":"006be074-0096-45e7-8982-2dbff4f49ce0","type":"BasicTicker"}},"id":"173d0e85-1564-4e3c-845e-9fec16962a4d","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"555678be-68f3-4cf7-8233-3d9495927257","subtype":"Figure","type":"Plot"},"ticker":{"id":"82f1966a-b67b-470d-a731-6342ffbdff15","type":"BasicTicker"}},"id":"5f417849-7d60-4b4b-b9ba-81a57a546734","type":"Grid"},{"attributes":{"plot":{"id":"b0d4d9e9-8fbb-4604-a677-062d0cc7dfac","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c09957b-6b4a-4b04-8503-6cca34683bd3","type":"BasicTicker"}},"id":"a84f35d4-d698-4849-b3b5-88e426f0d445","type":"Grid"},{"attributes":{"axis_label":"current [A]","formatter":{"id":"e96de649-6e93-432c-b48f-e7e73d179b9b","type":"BasicTickFormatter"},"plot":{"id":"9cba52d9-8a5a-4f09-a3b9-df4327db472c","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cc8afe2-b759-49b1-a690-b1cad5cd99e5","type":"BasicTicker"}},"id":"2f276ee5-3ecf-4511-b13d-24a6a3e54b2a","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4667f1ba-c7ff-4734-bc9e-27ef9acc032c","type":"PanTool"},{"id":"0f1ec046-7df9-4ae2-a92b-e29849dd7d11","type":"WheelZoomTool"},{"id":"5b0ea725-d11d-4f17-a369-0cd92fe19e96","type":"BoxZoomTool"},{"id":"a1a9b4ec-2471-4b9f-8546-5cebd348e312","type":"SaveTool"},{"id":"1 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[51]</strong>&gt;</code></p>

# %% [markdown]
# ## Case 4: Capacitor discharge to a resistor
#
# <img src="cap_discharge.png">

# %%
# Capacitor discharging to a resistor

def dk(y,t):
    u = y[0]
    
    du = -1/(R1*C)*u
    
    return [du]

# %%
y03 = [200.0]

# %%
X5 = odeint(dk, y03, t3)

# %%
u = X5[:,0]

# %%
p7 = figure(plot_width=800, plot_height=400, x_range = (0,4e-5))

p7.line(t3, u, color="firebrick")

p7.xaxis.axis_label = "time [s]"
p7.xaxis.axis_label_text_font_size = "10pt"
p7.yaxis.axis_label = "voltage [V]"
p7.yaxis.axis_label_text_font_size = "10pt"

show(p7)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="954a2973-611d-426b-84ad-dcfa5c1a7ea0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("954a2973-611d-426b-84ad-dcfa5c1a7ea0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '954a2973-611d-426b-84ad-dcfa5c1a7ea0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bdd85ca2-62fd-4218-ab3f-9cd7da0615f2":{"roots":{"references":[{"attributes":{},"id":"1d5398b3-348d-437d-99f9-fabe88efd5b1","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69840b85-fee7-44ed-8e4f-07ad30621e1d","type":"Line"},{"attributes":{"plot":{"id":"315d3066-4ae9-468f-8e8c-287022fa42ff","subtype":"Figure","type":"Plot"}},"id":"3d556da7-d6fb-4594-a64b-d677a00e7e37","type":"HelpTool"},{"attributes":{"plot":{"id":"315d3066-4ae9-468f-8e8c-287022fa42ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"1